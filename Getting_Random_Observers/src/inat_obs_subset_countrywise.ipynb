# %%
# %r
if(!require(maps)){install.packages("maps")}
library(maps)
if(!require(countrycode)){install.packages("countrycode")}
library(countrycode)

if(!require(data.table)){install.packages("data.table")}
#library(countrycode)

library(dplyr)
library(sparklyr) # load sparklyr last because there is namespace conflicts between dplyr and sparklyr by design
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <pre style = 'font-size:10p'>* installing *source* package ‘maps’ ...
# ** package ‘maps’ successfully unpacked and MD5 sums checked
# ** using staged installation
# checking for gawk... no
# checking for mawk... mawk
# configure: creating ./config.status
# config.status: creating src/Makefile
# ** libs
# ** arch -
# make -f &quot;/usr/lib/R/etc/Makeconf&quot; -f Makefile init.o mapclip.o mapget.o smooth.o thin.o
# make[1]: Entering directory '/tmp/RtmpXAHeQB/R.INSTALL91075cab3d1/maps/src'
# gcc -std=gnu99 -I&quot;/usr/share/R/include&quot; -DNDEBUG      -fpic  -g -O2 -fdebug-prefix-map=/build/r-base-tbZjLv/r-base-4.1.0=. -fstack-protector-strong -Wformat -Werror=format-security -Wdate-time -D_FORTIFY_SOURCE=2 -g  -c init.c -o init.o
# gcc -std=gnu99 -I&quot;/usr/share/R/include&quot; -DNDEBUG      -fpic  -g -O2 -fdebug-prefix-map=/build/r-base-tbZjLv/r-base-4.1.0=. -fstack-protector-strong -Wformat -Werror=format-security -Wdate-time -D_FORTIFY_SOURCE=2 -g  -c mapclip.c -o mapclip.o
# gcc -std=gnu99 -I&quot;/usr/share/R/include&quot; -DNDEBUG      -fpic  -g -O2 -fdebug-prefix-map=/build/r-base-tbZjLv/r-base-4.1.0=. -fstack-protector-strong -Wformat -Werror=format-security -Wdate-time -D_FORTIFY_SOURCE=2 -g  -c mapget.c -o mapget.o
# gcc -std=gnu99 -I&quot;/usr/share/R/include&quot; -DNDEBUG      -fpic  -g -O2 -fdebug-prefix-map=/build/r-base-tbZjLv/r-base-4.1.0=. -fstack-protector-strong -Wformat -Werror=format-security -Wdate-time -D_FORTIFY_SOURCE=2 -g  -c smooth.c -o smooth.o
# gcc -std=gnu99 -I&quot;/usr/share/R/include&quot; -DNDEBUG      -fpic  -g -O2 -fdebug-prefix-map=/build/r-base-tbZjLv/r-base-4.1.0=. -fstack-protector-strong -Wformat -Werror=format-security -Wdate-time -D_FORTIFY_SOURCE=2 -g  -c thin.c -o thin.o
# make[1]: Leaving directory '/tmp/RtmpXAHeQB/R.INSTALL91075cab3d1/maps/src'
# &quot;/usr/lib/R/bin/R&quot; CMD SHLIB -o maps.so init.o mapclip.o mapget.o smooth.o thin.o
# make[1]: Entering directory '/tmp/RtmpXAHeQB/R.INSTALL91075cab3d1/maps/src'
# gcc -std=gnu99 -shared -L/usr/lib/R/lib -Wl,-Bsymbolic-functions -Wl,-z,relro -o maps.so init.o mapclip.o mapget.o smooth.o thin.o -L/usr/lib/R/lib -lR
# make[1]: Leaving directory '/tmp/RtmpXAHeQB/R.INSTALL91075cab3d1/maps/src'
# make -f &quot;/usr/lib/R/etc/Makeconf&quot; -f Makefile Gmake
# make[1]: Entering directory '/tmp/RtmpXAHeQB/R.INSTALL91075cab3d1/maps/src'
# gcc -std=gnu99 -g -O2 -fdebug-prefix-map=/build/r-base-tbZjLv/r-base-4.1.0=. -fstack-protector-strong -Wformat -Werror=format-security -Wdate-time -D_FORTIFY_SOURCE=2 -g   -Wl,-Bsymbolic-functions -Wl,-z,relro  Gmake.c   -o Gmake
# make[1]: Leaving directory '/tmp/RtmpXAHeQB/R.INSTALL91075cab3d1/maps/src'
# make -f &quot;/usr/lib/R/etc/Makeconf&quot; -f Makefile Lmake
# make[1]: Entering directory '/tmp/RtmpXAHeQB/R.INSTALL91075cab3d1/maps/src'
# gcc -std=gnu99 -g -O2 -fdebug-prefix-map=/build/r-base-tbZjLv/r-base-4.1.0=. -fstack-protector-strong -Wformat -Werror=format-security -Wdate-time -D_FORTIFY_SOURCE=2 -g   -Wl,-Bsymbolic-functions -Wl,-z,relro  Lmake.c   -o Lmake
# make[1]: Leaving directory '/tmp/RtmpXAHeQB/R.INSTALL91075cab3d1/maps/src'
# make -f &quot;/usr/lib/R/etc/Makeconf&quot; -f Makefile world2.line
# make[1]: Entering directory '/tmp/RtmpXAHeQB/R.INSTALL91075cab3d1/maps/src'
# Converting world to world2
# mawk -f ./convert.awk &lt; world.line &gt; world2.line
# make[1]: Leaving directory '/tmp/RtmpXAHeQB/R.INSTALL91075cab3d1/maps/src'
# make -f &quot;/usr/lib/R/etc/Makeconf&quot; -f Makefile county.L state.L usa.L nz.L world.L world2.L italy.L france.L state.vbm.L state.carto.L lakes.L
# make[1]: Entering directory '/tmp/RtmpXAHeQB/R.INSTALL91075cab3d1/maps/src'
# ./Lmake 0 s b county.line county.linestats ../inst/mapdata/county.L
# ./Lmake 0 s b state.line state.linestats ../inst/mapdata/state.L
# ./Lmake 0 s b usa.line usa.linestats ../inst/mapdata/usa.L
# ./Lmake 0 s b nz.line nz.linestats ../inst/mapdata/nz.L
# ./Lmake 0 s b world.line world.linestats ../inst/mapdata/world.L
# ./Lmake 0 s b world2.line world2.linestats ../inst/mapdata/world2.L
# ./Lmake 0 s b italy.line italy.linestats ../inst/mapdata/italy.L
# ./Lmake 0 s b france.line france.linestats ../inst/mapdata/france.L
# ./Lmake 0 p b state.vbm.line state.vbm.linestats ../inst/mapdata/state.vbm.L
# ./Lmake 0 p b state.carto.line state.carto.linestats ../inst/mapdata/state.carto.L
# ./Lmake 0 s b lakes.line lakes.linestats ../inst/mapdata/lakes.L
# make[1]: Leaving directory '/tmp/RtmpXAHeQB/R.INSTALL91075cab3d1/maps/src'
# make -f &quot;/usr/lib/R/etc/Makeconf&quot; -f Makefile county.G state.G usa.G nz.G world.G world2.G italy.G france.G state.vbm.G state.carto.G lakes.G
# make[1]: Entering directory '/tmp/RtmpXAHeQB/R.INSTALL91075cab3d1/maps/src'
# ./Gmake b county.gon county.gonstats ../inst/mapdata/county.G ../inst/mapdata/county.L
# ./Gmake b state.gon state.gonstats ../inst/mapdata/state.G ../inst/mapdata/state.L
# ./Gmake b usa.gon usa.gonstats ../inst/mapdata/usa.G ../inst/mapdata/usa.L
# ./Gmake b nz.gon nz.gonstats ../inst/mapdata/nz.G ../inst/mapdata/nz.L
# ./Gmake b world.gon world.gonstats ../inst/mapdata/world.G ../inst/mapdata/world.L
# ./Gmake b world2.gon world2.gonstats ../inst/mapdata/world2.G ../inst/mapdata/world2.L
# ./Gmake b italy.gon italy.gonstats ../inst/mapdata/italy.G ../inst/mapdata/italy.L
# ./Gmake b france.gon france.gonstats ../inst/mapdata/france.G ../inst/mapdata/france.L
# ./Gmake b state.vbm.gon state.vbm.gonstats ../inst/mapdata/state.vbm.G ../inst/mapdata/state.vbm.L
# ./Gmake b state.carto.gon state.carto.gonstats ../inst/mapdata/state.carto.G ../inst/mapdata/state.carto.L
# ./Gmake b lakes.gon lakes.gonstats ../inst/mapdata/lakes.G ../inst/mapdata/lakes.L
# make[1]: Leaving directory '/tmp/RtmpXAHeQB/R.INSTALL91075cab3d1/maps/src'
# make -f &quot;/usr/lib/R/etc/Makeconf&quot; -f Makefile county.N state.N usa.N nz.N world.N world2.N italy.N france.N state.vbm.N state.carto.N lakes.N
# make[1]: Entering directory '/tmp/RtmpXAHeQB/R.INSTALL91075cab3d1/maps/src'
# make[1]: Leaving directory '/tmp/RtmpXAHeQB/R.INSTALL91075cab3d1/maps/src'
# installing to /local_disk0/.ephemeral_nfs/envs/rEnv-81cbc0c4-1187-4695-949a-97f30c922713/00LOCK-maps/00new/maps/libs
# ** R
# ** data
# *** moving datasets to lazyload DB
# ** inst
# ** byte-compile and prepare package for lazy loading
# ** help
# *** installing help indices
# ** building package indices
# ** testing if installed package can be loaded from temporary location
# ** checking absolute paths in shared objects and dynamic libraries
# ** testing if installed package can be loaded from final location
# ** testing if installed package keeps a record of temporary installation path
# * DONE (maps)
# * installing *source* package ‘countrycode’ ...
# ** package ‘countrycode’ successfully unpacked and MD5 sums checked
# ** using staged installation
# ** R
# ** data
# *** moving datasets to lazyload DB
# ** inst
# ** byte-compile and prepare package for lazy loading
# ** help
# *** installing help indices
# ** building package indices
# ** testing if installed package can be loaded from temporary location
# ** testing if installed package can be loaded from final location
# ** testing if installed package keeps a record of temporary installation path
# * DONE (countrycode)
# </pre><pre style = 'font-size:10p'>Loading required package: maps
# Warning in library(package, lib.loc = lib.loc, character.only = TRUE, logical.return = TRUE,  :
#   there is no package called ‘maps’
# Installing package into ‘/local_disk0/.ephemeral_nfs/envs/rEnv-81cbc0c4-1187-4695-949a-97f30c922713’
# (as ‘lib’ is unspecified)
# trying URL 'https://cloud.r-project.org/src/contrib/maps_3.4.0.tar.gz'
# Content type 'application/x-gzip' length 2278225 bytes (2.2 MB)
# ==================================================
# downloaded 2.2 MB
#
#
# The downloaded source packages are in
# 	‘/tmp/Rt

# %%
# %r sessionInfo()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <pre style = 'font-size:10p'></pre><pre style = 'font-size:10p'>R version 4.1.0 (2021-05-18)
# Platform: x86_64-pc-linux-gnu (64-bit)
# Running under: Ubuntu 20.04.3 LTS
#
# Matrix products: default
# BLAS:   /usr/lib/x86_64-linux-gnu/blas/libblas.so.3.9.0
# LAPACK: /usr/lib/x86_64-linux-gnu/lapack/liblapack.so.3.9.0
#
# locale:
#  [1] LC_CTYPE=C.UTF-8       LC_NUMERIC=C           LC_TIME=C.UTF-8
#  [4] LC_COLLATE=C.UTF-8     LC_MONETARY=C.UTF-8    LC_MESSAGES=C.UTF-8
#  [7] LC_PAPER=C.UTF-8       LC_NAME=C              LC_ADDRESS=C
# [10] LC_TELEPHONE=C         LC_MEASUREMENT=C.UTF-8 LC_IDENTIFICATION=C
#
# attached base packages:
# [1] stats     graphics  grDevices utils     datasets  methods   base
#
# other attached packages:
# [1] sparklyr_1.7.1    dplyr_1.0.7       data.table_1.14.0 countrycode_1.3.0
# [5] maps_3.4.0
#
# loaded via a namespace (and not attached):
#  [1] pillar_1.6.1       compiler_4.1.0     dbplyr_2.1.1       TeachingDemos_2.10
#  [5] r2d3_0.2.5         base64enc_0.1-3    tools_4.1.0        uuid_0.1-4
#  [9] digest_0.6.27      jsonlite_1.7.2     lifecycle_1.0.0    tibble_3.1.3
# [13] pkgconfig_2.0.3    rlang_0.4.11       cli_3.0.1          DBI_1.1.1
# [17] rstudioapi_0.13    parallel_4.1.0     yaml_2.2.1         stringr_1.4.0
# [21] withr_2.4.2        httr_1.4.2         hwriter_1.3.2      generics_0.1.0
# [25] vctrs_0.3.8        htmlwidgets_1.5.3  rprojroot_2.0.2    tidyselect_1.1.1
# [29] glue_1.4.2         forge_0.2.0        R6_2.5.0           fansi_0.5.0
# [33] blob_1.2.2         purrr_0.3.4        tidyr_1.1.3        SparkR_3.1.1
# [37] magrittr_2.0.1     hwriterPlus_1.0-3  ellipsis_0.3.2     htmltools_0.5.1.1
# [41] assertthat_0.2.1   Rserve_1.8-8       config_0.3.1       utf8_1.2.2
# [45] stringi_1.7.3      crayon_1.4.1
#
# </pre>

# %%
# %r
#inat_plant_post2015 <- sdf_sql(sc,
#"SELECT kingdom,eventdate,recordedBy,occurrenceid,countrycode,scientificname FROM gbif.inat
#WHERE kingdom = 'Plantae' AND SUBSTRING(eventdate,1,4)>2015"
#       ) 

#active_collectors <- inat_plant_post2015 %>%
#  filter(countrycode == "BE") %>%
#  dplyr::count(recordedBy) %>%
#  filter(n>99) %>%
#  pull(recordedBy)
  
#get_active_collectors_for_country <- function(countrycode,cutoff=100){
#  active_collectors <- inat_plant_post2015 %>%
#  filter(countrycode == countrycode) %>%
#  dplyr::count(recordedBy) %>%
#  filter(n>(cutoff - 1)) %>%
#  pull(recordedBy)  
#}
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>

# %% [markdown]
# Explore GBIF data for plants after a certain era, takes about 5 minutes to run
#
# ```
# %sql
#
# SELECT kingdom,eventdate,recordedBy,occurrenceid FROM gbif.inat
# WHERE kingdom = 'Plantae' AND SUBSTRING(eventdate,1,4)>2015
# LIMIT 500
# ```

# %%
# %r
# declare spark cluster
sc <- sparklyr::spark_connect(method = "databricks")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <pre style = 'font-size:10p'></pre><pre style = 'font-size:10p'>
# </pre>

# %%
# %r
#sel_cc <- "BE"

#active_collectors <- get_active_collectors_for_country(sel_cc, cutoff=100)

#out_obs <- inat_plant_post2015 %>%
#  filter(countrycode == sel_cc) %>%
#  filter(recordedBy %in% active_collectors)

#SparkR::as.data.frame(out_obs) %>% display
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>

# %%
# %r
#length(active_collectors)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>

# %% [markdown]
# Fetching the iNaturalist opendata dump from a Meise server (instead of Amazon S3, because I don't want to set it all up)

# %%
# %r

#url_to_get <- "https://oxalis.br.fgov.be/images/observations.csv.gz"
#options(timeout = max(1000, getOption("timeout"))) #set timeout to something long
#download.file(url = url_to_get, destfile= "/dbfs/FileStore/observations.csv.gz")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>

# %%
# %r
# check if we got exactly the right file (the download didn't fail or the file didn't change)
#tools::md5sum("/dbfs/FileStore/observations.csv.gz") == "bbfc3c2536acd7010d06c50970b03237"
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>

# %% [markdown]
# d
#
# ## We are looking for:
#
# - only european countries
# - at least 20 observations over the lifetime of the user, in the country we are exporting
# - only observations that need id or research grade
# - any taxa
#
# Then we want to split these out by country, label the output files by two character iso code
#
# **Let's target Spain first**

# %%
# %r
#inat_open_data <- spark_read_csv(sc, path = "dbfs:/FileStore/observations.csv.gz", name = "inat_open_data", delimiter="\t")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>

# %% [markdown]
# store it as a parquet for reference (and so we don't need to do this again if we run the notebook in the future)

# %%
# %sql 
CREATE TABLE pieter.inat_data
STORED AS parquet
AS SELECT * FROM inat_open_data
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>

# %%
# %r
# it takes around 11 minutes to load in this big parquet dataset
inat_open_data <- sdf_sql(sc,"SELECT * FROM pieter.inat_data")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <pre style = 'font-size:10p'></pre><pre style = 'font-size:10p'>
# </pre>

# %%
# %r
#sdf_sql(sc,"SELECT * FROM pieter.inat_data") %>% sdf_nrow()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>

# %%
# %r
#glimpse(inat_open_data)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>

# %% [markdown]
# ### Filter out casual observations

# %%
# %r
# filter out the casual observations

inat_open_data <- inat_open_data %>%
  filter(quality_grade != "casual")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <pre style = 'font-size:10p'></pre><pre style = 'font-size:10p'>
# </pre>

# %% [markdown]
# ### Filter out inactive users on a global scale

# %%
# %r
# get a total tally for the users so we can get rid of ones that don't have 20 observations

user_tally <- sdf_sql(sc,"SELECT observer_id,COUNT(*) as N FROM pieter.inat_data GROUP BY observer_id")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <pre style = 'font-size:10p'></pre><pre style = 'font-size:10p'>
# </pre>

# %%
# %r
#sdf_nrow(user_tally)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>

# %%
# %r
active_users <- pull(filter(user_tally,N>19),observer_id)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <pre style = 'font-size:10p'></pre><pre style = 'font-size:10p'>
# </pre>

# %%
# %r
# exploring howmany users have at least 20 observations
#length(active_users)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>

# %%
# %r
# dropping all observations by users that have less than 20 observations
inat_open_data <- filter(inat_open_data, observer_id %in% active_users)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <pre style = 'font-size:10p'></pre><pre style = 'font-size:10p'>
# </pre>

# %%
# %r
#sdf_nrow(inat_open_data)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>

# %% [markdown]
# ### Add country information: using UK as a manual example

# %%
# %r
#inat_uk <- 
#  inat_open_data %>%
#  filter(longitude > -7) %>%
#  filter(longitude < 2) %>%
#  filter(latitude > 49) %>%
#  filter(latitude < 59)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>

# %%
# %r
#longs <- pull(inat_uk,longitude)
#lats <- pull(inat_uk,latitude)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>

# %%
# %r
#countries <- maps::map.where(database = "world", x = longs, y = lats)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>

# %%
# %r
#sdf_copy_to(sc,tibble(country=countries),name = "countries", overwrite = TRUE)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>

# %%
# %r
# merge the country information to the observers, and filter so it's only from the chosen country
#inat_uk <- sdf_bind_cols(inat_uk,sdf_sql(sc,"SELECT * FROM countries")) %>%
#  filter(country == "UK:Great Britain")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>

# %% [markdown]
# drop observations of observers with less then 20 observers in the uk

# %%
# %r
#active_observers <- filter(count(inat_uk,observer_id),n>19) %>% pull(observer_id)
#inat_uk <- filter(inat_uk, observer_id %in% active_observers)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>

# %%
# %r
#sdf_nrow(inat_uk)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>

# %%
# %r
#select(inat_uk, - country) %>% sdf_collect() %>% data.table::fwrite("/dbfs/FileStore/UK_inat.csv")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>

# %%
# %r
#select(inat_uk, - country) %>% sdf_collect() %>% saveRDS("/dbfs/FileStore/UK_inat.rds")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>

# %% [markdown]
# ## Now for any country

# %%
# %r
# loading in bounding boxes for the countries of the world, taken from a github gist
bounding_boxes <- sdf_sql(sc,"SELECT * FROM pieter.bounding_boxes") %>% sdf_collect()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <pre style = 'font-size:10p'></pre><pre style = 'font-size:10p'>
# </pre>

# %%
# %r
# Let's have a look at the bounding boxes we have for the countries of the world
SparkR::as.data.frame(bounding_boxes) %>% display
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>iso2c</th><th>long_min</th><th>lat_min</th><th>long_max</th><th>lat_max</th><th>country_name</th></tr></thead><tbody><tr><td>AF</td><td>60.5284298033</td><td>29.318572496</td><td>75.1580277851</td><td>38.4862816432</td><td>Afghanistan</td></tr><tr><td>AO</td><td>11.6400960629</td><td>-17.9306364885</td><td>24.0799052263</td><td>-4.43802336998</td><td>Angola</td></tr><tr><td>AL</td><td>19.3044861183</td><td>39.624997667</td><td>21.0200403175</td><td>42.6882473822</td><td>Albania</td></tr><tr><td>AE</td><td>51.5795186705</td><td>22.4969475367</td><td>56.3968473651</td><td>26.055464179</td><td>United Arab Emirates</td></tr><tr><td>AR</td><td>-73.4154357571</td><td>-55.25</td><td>-53.628348965</td><td>-21.8323104794</td><td>Argentina</td></tr><tr><td>AM</td><td>43.5827458026</td><td>38.7412014837</td><td>46.5057198423</td><td>41.2481285671</td><td>Armenia</td></tr><tr><td>AQ</td><td>-180.0</td><td>-90.0</td><td>180.0</td><td>-63.2706604895</td><td>Antarctica</td></tr><tr><td>TF</td><td>68.72</td><td>-49.775</td><td>70.56</td><td>-48.625</td><td>French Southern Territories</td></tr><tr><td>AU</td><td>113.338953078</td><td>-43.6345972634</td><td>153.569469029</td><td>-10.6681857235</td><td>Australia</td></tr><tr><td>AT</td><td>9.47996951665</td><td>46.4318173285</td><td>16.9796667823</td><td>49.0390742051</td><td>Austria</td></tr><tr><td>AZ</td><td>44.7939896991</td><td>38.2703775091</td><td>50.3928210793</td><td>41.8606751572</td><td>Azerbaijan</td></tr><tr><td>BI</td><td>29.0249263852</td><td>-4.49998341229</td><td>30.752262811</td><td>-2.34848683025</td><td>Burundi</td></tr><tr><td>BE</td><td>2.51357303225</td><td>49.5294835476</td><td>6.15665815596</td><td>51.4750237087</td><td>Belgium</td></tr><tr><td>BJ</td><td>0.772335646171</td><td>6.14215770103</td><td>3.79711225751</td><td>12.2356358912</td><td>Benin</td></tr><tr><td>BF</td><td>-5.47056494793</td><td>9.61083486576</td><td>2.17710778159</td><td>15.1161577418</td><td>Burkina Faso</td></tr><tr><td>BD</td><td>88.0844222351</td><td>20.670883287</td><td>92.6727209818</td><td>26.4465255803</td><td>Bangladesh</td></tr><tr><td>BG</td><td>22.3805257504</td><td>41.2344859889</td><td>28.5580814959</td><td>44.2349230007</td><td>Bulgaria</td></tr><tr><td>BS</td><td>-78.98</td><td>23.71</td><td>-77.0</td><td>27.04</td><td>Bahamas</td></tr><tr><td>BA</td><td>15.7500260759</td><td>42.65</td><td>19.59976</td><td>45.2337767604</td><td>Bosnia & Herzegovina</td></tr><tr><td>BY</td><td>23.1994938494</td><td>51.3195034857</td><td>32.6936430193</td><td>56.1691299506</td><td>Belarus</td></tr><tr><td>BZ</td><td>-89.2291216703</td><td>15.8869375676</td><td>-88.1068129138</td><td>18.4999822047</td><td>Belize</td></tr><tr><td>BO</td><td>-69.5904237535</td><td>-22.8729187965</td><td>-57.4983711412</td><td>-9.76198780685</td><td>Bolivia</td></tr><tr><td>BR</td><td>-73.9872354804</td><td>-33.7683777809</td><td>-34.7299934555</td><td>5.24448639569</td><td>Brazil</td></tr><tr><td>BN</td><td>114.204016555</td><td>4.007636827</td><td>115.450710484</td><td>5.44772980389</td><td>Brunei</td></tr><tr><td>BT</td><td>88.8142484883</td><td>26.7194029811</td><td>92.1037117859</td><td>28.2964385035</td><td>Bhutan</td></tr><tr><td>BW</td><td>19.8954577979</td><td>-26.8285429827</td><td>29.4321883481</td><td>-17.6618156877</td><td>Botswana</td></tr><tr><td>CF</td><td>14.4594071794</td><td>2.2676396753</td><td>27.3742261085</td><td>11.1423951278</td><td>Central African Republic</td></tr><tr><td>CA</td><td>-140.99778</td><td>41.6751050889</td><td>-52.6480987209</td><td>83.23324</td><td>Canada</td></tr><tr><td>CH</td><td>6.02260949059</td><td>45.7769477403</td><td>10.4427014502</td><td>47.8308275417</td><td>Switzerland</td></tr><tr><td>CL</td><td>-75.6443953112</td><td>-55.61183</td><td>-66.95992</td><td>-17.5800118954</td><td>Chile</td></tr><tr><td>CN</td><td>73.6753792663</td><td>18.197700914</td><td>13 ...
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <pre style = 'font-size:10p'></pre><pre style = 'font-size:10p'>
# </pre>

# %%
# %r
selected_country <- "CZ"
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <pre style = 'font-size:10p'></pre><pre style = 'font-size:10p'>
# </pre>

# %%
# %r 
# run example of part of function to see if we can get rid of size limitation and get rid of filter
selected_bb <- filter(bounding_boxes,iso2c == selected_country)

inat_subset <-
  inat_open_data %>%
  filter(longitude > !!selected_bb$long_min) %>%
  filter(longitude < !!selected_bb$long_max) %>%
  filter(latitude > !!selected_bb$lat_min) %>%
  filter(latitude < !!selected_bb$lat_max)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <pre style = 'font-size:10p'></pre><pre style = 'font-size:10p'>
# </pre>

# %%
# %r
# check size of subset, the problem with Russia is that it's bounding box is huge. Taking in almost half of the worlds observations. So we check the number of observations captured here.
message(sprintf("The selected subset has %i rows",sparklyr::sdf_nrow(inat_subset)))
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <pre style = 'font-size:10p'></pre><pre style = 'font-size:10p'>The selected subset has 278940 rows
#
# </pre>

# %%
# %r

# Let's try to avoid having to reverse geocode every observation, as for some big countries R can't handle this out of the box (object size limits?)
# SEE ALSO: https://gis.stackexchange.com/questions/8650/measuring-accuracy-of-latitude-and-longitude/

decimals_to_round_to <- 1 # around 10-15km is enough resolution for country level

# run example of part of function to see if we can get rid of size limitation and get rid of filter
# selected_bb <- filter(bounding_boxes,iso2c == selected_country) # did this already in the clell above

# inat_subset <- # we did this earlier already
#  inat_open_data %>%
#  filter(longitude > !!selected_bb$long_min) %>%
#  filter(longitude < !!selected_bb$long_max) %>%
#  filter(latitude > !!selected_bb$lat_min) %>%
#  filter(latitude < !!selected_bb$lat_max)

inat_rounded <- 
  inat_subset %>%
    mutate(longitude_rounded = round(longitude,decimals_to_round_to),
           latitude_rounded = round(latitude,decimals_to_round_to)) %>%
    mutate(loc_id = paste0(longitude_rounded,latitude_rounded)) 

inat_locs <- inat_rounded %>%
  select(loc_id, longitude_rounded, latitude_rounded) %>%
  sparklyr::distinct()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <pre style = 'font-size:10p'></pre><pre style = 'font-size:10p'>
# </pre>

# %%
# %r
# Check howmany unique locations we end up with after rounding
message(sprintf("Found %i unique localities after rounding to %i decimals",sparklyr::sdf_nrow(inat_locs), decimals_to_round_to))
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <pre style = 'font-size:10p'></pre><pre style = 'font-size:10p'>Warning: ORDER BY is ignored in subqueries without LIMIT
# ℹ Do you need to move arrange() later in the pipeline or use window_order() instead?
# Found 1630 unique localities after rounding to 1 decimals
#
# </pre>

# %%
# %r

# use base:with instead of dplyr:pull to do reverse georeferencing in the local r environement

rev_georeferenced <- with(sparklyr::collect(inat_locs), 
       tibble(
         loc_id = loc_id,
         country = maps::map.where(database = "world", x = longitude_rounded, y = latitude_rounded)
       )
    )
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <pre style = 'font-size:10p'></pre><pre style = 'font-size:10p'>
# </pre>

# %%
# %r # use base:with instead
#sdf_copy_to(sc,
#            tibble(loc_id = pull(inat_locs,loc_id),
#                   country=maps::map.where(database = "world", x = pull(inat_locs,longitude_rounded), y = pull(inat_locs,latitude_rounded))),
#            name = "cc_rounded", overwrite = TRUE)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <pre style = 'font-size:10p'></pre><pre style = 'font-size:10p'>Warning: ORDER BY is ignored in subqueries without LIMIT
# ℹ Do you need to move arrange() later in the pipeline or use window_order() instead?
# Warning: ORDER BY is ignored in subqueries without LIMIT
# ℹ Do you need to move arrange() later in the pipeline or use window_order() instead?
# Warning: ORDER BY is ignored in subqueries without LIMIT
# ℹ Do you need to move arrange() later in the pipeline or use window_order() instead?
# Warning: ORDER BY is ignored in subqueries without LIMIT
# ℹ Do you need to move arrange() later in the pipeline or use window_order() instead?
# Warning: ORDER BY is ignored in subqueries without LIMIT
# ℹ Do you need to move arrange() later in the pipeline or use window_order() instead?
# Warning: ORDER BY is ignored in subqueries without LIMIT
# ℹ Do you need to move arrange() later in the pipeline or use window_order() instead?
# Warning: ORDER BY is ignored in subqueries without LIMIT
# ℹ Do you need to move arrange() later in the pipeline or use window_order() instead?
# Warning: ORDER BY is ignored in subqueries without LIMIT
# ℹ Do you need to move arrange() later in the pipeline or use window_order() instead?
# Warning: ORDER BY is ignored in subqueries without LIMIT
# ℹ Do you need to move arrange() later in the pipeline or use window_order() instead?
# # Source: spark&lt;cc_rounded&gt; [?? x 2]
#    loc_id   country
#    &lt;chr&gt;    &lt;chr&gt;
#  1 15.843.0 Bosnia and Herzegovina
#  2 15.843.6 Bosnia and Herzegovina
#  3 15.843.7 &lt;NA&gt;
#  4 15.843.8 Bosnia and Herzegovina
#  5 15.843.9 Bosnia and Herzegovina
#  6 15.844.2 Croatia
#  7 15.844.3 &lt;NA&gt;
#  8 15.844.5 Croatia
#  9 15.844.6 &lt;NA&gt;
# 10 15.844.7 Bosnia and Herzegovina
# # … with more rows
#
# </pre>

# %%
# %r 
sdf_copy_to(sc,rev_georeferenced,name = "cc_rounded", overwrite = TRUE)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <pre style = 'font-size:10p'></pre><pre style = 'font-size:10p'># Source: spark&lt;cc_rounded&gt; [?? x 2]
#    loc_id   country
#    &lt;chr&gt;    &lt;chr&gt;
#  1 17.149.6 Czech Republic
#  2 14.249.9 Czech Republic
#  3 14.450.1 Czech Republic
#  4 15.850.1 Czech Republic
#  5 17.049.5 Czech Republic
#  6 13.549.7 Czech Republic
#  7 13.049.0 Germany
#  8 13.249.1 Germany
#  9 17.349.2 Czech Republic
# 10 17.349.3 Czech Republic
# # … with more rows
#
# </pre>

# %%
# %r

inat_rounded_revgeoloc <- sparklyr::left_join(inat_rounded,spark_read_table(sc,"cc_rounded"), by = "loc_id")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <pre style = 'font-size:10p'></pre><pre style = 'font-size:10p'>
# </pre>

# %%
# %r

sdf_register(inat_rounded_revgeoloc,name="countries")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <pre style = 'font-size:10p'></pre><pre style = 'font-size:10p'># Source: spark&lt;countries&gt; [?? x 12]
#    observation_uuid     observer_id latitude longitude positional_accu… taxon_id
#    &lt;chr&gt;                      &lt;int&gt;    &lt;dbl&gt;     &lt;dbl&gt;            &lt;int&gt;    &lt;int&gt;
#  1 406a32c8-8d42-4f77-…        1000     49.8      14.7               NA      981
#  2 e11bd85e-4f43-4145-…        1000     50.1      14.4               NA     3048
#  3 409d8125-9631-4bb4-…        1000     50.1      14.4               NA     8088
#  4 00ab8328-dab9-465e-…        1000     50.1      14.4               NA     6921
#  5 3ab4e52a-619a-4ade-…        2851     48.8      16.6               50    35912
#  6 c60de3aa-4cea-4d05-…        2851     48.8      16.6               50    35912
#  7 eb6d87c0-6c9f-40f5-…        1620     50.1      14.4               NA     8088
#  8 32def1d7-af26-412a-…        9287     50.7      13.2               NA   341154
#  9 282fa77d-d911-4688-…        9287     50.8      13.0               NA    35453
# 10 ac445423-1834-4f19-…        9287     50.8      13.0               NA    57443
# # … with more rows, and 6 more variables: quality_grade &lt;chr&gt;,
# #   observed_on &lt;chr&gt;, longitude_rounded &lt;dbl&gt;, latitude_rounded &lt;dbl&gt;,
# #   loc_id &lt;chr&gt;, country &lt;chr&gt;
#
# </pre>

# %%
# %r
# filter mechanism, drop observations that didn't geocode to the selected country

# use the filter if we can, otherwise count the most common country and use that. In some countries the last solution wouldn't work as there are more active countries in the same bounding box, for example; Afganistan.

cc_tally <- sdf_sql(sc,"SELECT country,COUNT(*) as N FROM countries GROUP BY country ORDER BY N DESC") %>% sdf_collect()
if(countrycode::countrycode(selected_country, origin= "iso2c", destination="country.name") %>% stringr::str_replace("&","and") %in% pull(cc_tally,country)){
  inat_subset <- spark_read_table(sc,"countries") %>%
    filter(country == stringr::str_replace(countrycode::countrycode(selected_country, origin= "iso2c", destination="country.name"),"&","and"))} else {
  inat_subset <- spark_read_table(sc,"countries") %>%
    filter(country == pull(dplyr::slice(cc_tally,1),country))
}
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <pre style = 'font-size:10p'></pre><pre style = 'font-size:10p'>
# </pre>

# %%
# %r # test cell to investigate filter mechanism

cc_tally <- sdf_sql(sc,"SELECT country,COUNT(*) as N FROM countries GROUP BY country ORDER BY N DESC") %>% sdf_collect()
inat_subset <- spark_read_table(sc,"countries") %>%
    filter(country == pull(dplyr::slice(cc_tally,1),country))

# %%
# %r SparkR::as.data.frame(inat_subset) %>% display
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>observation_uuid</th><th>observer_id</th><th>latitude</th><th>longitude</th><th>positional_accuracy</th><th>taxon_id</th><th>quality_grade</th><th>observed_on</th><th>longitude_rounded</th><th>latitude_rounded</th><th>loc_id</th><th>country</th></tr></thead><tbody><tr><td>0c40c795-9a81-4872-ba40-6109fd2edd86</td><td>30141</td><td>43.29345</td><td>18.696671</td><td>1546</td><td>123628</td><td>research</td><td>2010-08-16</td><td>18.7</td><td>43.3</td><td>18.743.3</td><td>Bosnia and Herzegovina</td></tr><tr><td>f87389e3-fd6c-46b4-932a-a1a5f3ed75d5</td><td>30141</td><td>44.48426</td><td>16.961517</td><td>3040</td><td>118936</td><td>research</td><td>2010-08-18</td><td>17.0</td><td>44.5</td><td>17.044.5</td><td>Bosnia and Herzegovina</td></tr><tr><td>74e0ae4d-6ec7-449f-8eef-0fa677d13033</td><td>20957</td><td>43.065543</td><td>17.752989</td><td>24</td><td>55658</td><td>research</td><td>2014-06-18</td><td>17.8</td><td>43.1</td><td>17.843.1</td><td>Bosnia and Herzegovina</td></tr><tr><td>929644ad-7e20-4d93-890a-38d338ea554b</td><td>89890</td><td>43.957697</td><td>19.427133</td><td>11</td><td>47516</td><td>research</td><td>2008-07-20</td><td>19.4</td><td>44.0</td><td>19.444.0</td><td>Bosnia and Herzegovina</td></tr><tr><td>13664a03-ea1c-4910-9fe8-4ba7b0fae9c4</td><td>89890</td><td>43.243533</td><td>18.606248</td><td>193</td><td>131586</td><td>research</td><td>2008-09-01</td><td>18.6</td><td>43.2</td><td>18.643.2</td><td>Bosnia and Herzegovina</td></tr><tr><td>937be328-d79a-4ad3-9e96-81951f2b97bc</td><td>89890</td><td>43.317485</td><td>18.662338</td><td>2747</td><td>334194</td><td>research</td><td>2007-07-04</td><td>18.7</td><td>43.3</td><td>18.743.3</td><td>Bosnia and Herzegovina</td></tr><tr><td>ea5e23d4-ce46-4863-86c7-72e5449d2cc7</td><td>89890</td><td>43.31069</td><td>18.660278</td><td>1547</td><td>133295</td><td>research</td><td>2007-07-04</td><td>18.7</td><td>43.3</td><td>18.743.3</td><td>Bosnia and Herzegovina</td></tr><tr><td>29742d85-7e4e-4d43-9cc7-0065d878b61b</td><td>173306</td><td>43.225193</td><td>17.511864</td><td>1549</td><td>51825</td><td>needs_id</td><td>2012-07-24</td><td>17.5</td><td>43.2</td><td>17.543.2</td><td>Bosnia and Herzegovina</td></tr><tr><td>f50998d9-0274-4492-ba04-69aa1e857e1e</td><td>284168</td><td>44.5140790088</td><td>18.4741973877</td><td>15</td><td>891696</td><td>research</td><td>2014-03-20</td><td>18.5</td><td>44.5</td><td>18.544.5</td><td>Bosnia and Herzegovina</td></tr><tr><td>77184a6e-a08a-437d-a242-a9ce70db626e</td><td>284168</td><td>44.5141260591</td><td>18.4735107422</td><td>61</td><td>55746</td><td>research</td><td>2016-08-01</td><td>18.5</td><td>44.5</td><td>18.544.5</td><td>Bosnia and Herzegovina</td></tr><tr><td>ab3146c7-6b53-4fcf-a56b-5283026ed4ff</td><td>284168</td><td>44.513942447</td><td>18.4736394882</td><td>61</td><td>207977</td><td>research</td><td>2016-07-05</td><td>18.5</td><td>44.5</td><td>18.544.5</td><td>Bosnia and Herzegovina</td></tr><tr><td>41add4d9-29d4-4765-8cd1-6fa43f1aff6d</td><td>284168</td><td>44.5140036511</td><td>18.4734249115</td><td>61</td><td>348017</td><td>research</td><td>2016-08-06</td><td>18.5</td><td>44.5</td><td>18.544.5</td><td>Bosnia and Herzegovina</td></tr><tr><td>40ca769e-edb5-4a0b-b86b-27f0d5baa7e6</td><td>284168</td><td>44.5141260591</td><td>18.4734678268</td><td>61</td><td>56293</td><td>research</td><td>2013-07-01</td><td>18.5</td><td>44.5</td><td>18.544.5</td><td>Bosnia and Herzegovina</td></tr><tr><td>b0a97669-00f6-4a50-b4da-fe37e617bbbb</td><td>284168</td><td>44.5138549763</td><td>18.4731674194</td><td>31</td><td>144757</td><td>research</td><td>2014-03-30</td><td>18.5</td><td>44.5</td><td>18.544.5</td><td>Bosnia and Herzegovina</td></tr><tr><td>a53f16b4-a3f3-4110-8739-a3ef69ab6963</td><td>284168</td><td>44.5140538897</td><td>18.4732532501</td><td>31</td><td>3017</td><td>research</td><td>2014-03-21</td><td>18.5</td><td>44.5</td><td>1 ...
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <pre style = 'font-size:10p'></pre><pre style = 'font-size:10p'>Warning in sdf_collect_static(object, impl, ...) :
#   NAs introduced by coercion to integer range
#
# </pre>

# %%
# %r

# old version of function to fetch observations for a given country, with a cutoff for active observers only
fetch_countrywise_old <- function(selected_country, cutoff = 20){

selected_bb <- filter(bounding_boxes,iso2c == selected_country)

inat_subset <-
  inat_open_data %>%
  filter(longitude > !!selected_bb$long_min) %>%
  filter(longitude < !!selected_bb$long_max) %>%
  filter(latitude > !!selected_bb$lat_min) %>%
  filter(latitude < !!selected_bb$lat_max)

# fetch coordinates to R env
longs <- pull(inat_subset,longitude)
lats <- pull(inat_subset,latitude)

# compare to shapefiles in local db, and push back to spark
sdf_copy_to(sc,tibble(country=maps::map.where(database = "world", x = longs, y = lats)),name = "countries", overwrite = TRUE)
  
# merge the country information to the observers, and filter so it's only from the chosen country
inat_subset <- sdf_bind_cols(inat_subset,sdf_sql(sc,"SELECT * FROM countries")) %>%
  filter(country == countrycode::countrycode(selected_country, origin= "iso2c", destination="country.name"))
# drop records of observers with less than the cutoff records
active_observers <- filter(count(inat_subset,observer_id),n>(cutoff-1)) %>% pull(observer_id)
inat_subset <- filter(inat_subset, observer_id %in% active_observers)
  
# print a short message about the result, the rowcount in the end is an expensive step that we don't really need
message(sprintf("passed %s: %s, subsetting resulted in %i records",selected_country, countrycode::countrycode(selected_country, origin = "iso2c", destination = "country.name"), sdf_nrow(inat_subset)))
# return subset
return(inat_subset)
  }
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>

# %%
# %r
# new version of the above function, this time implementing rounding in the coordinates so not every observation needs to be georeferenced, and also implementing an alternative filter mechanism so if there is no exact match to a country in the result list, the most common country gets chosen.

fetch_countrywise <- function(selected_country, cutoff = 20, decimals_to_round_to = 2){

selected_bb <- filter(bounding_boxes,iso2c == selected_country)

inat_subset <-
  inat_open_data %>%
  filter(longitude > !!selected_bb$long_min) %>%
  filter(longitude < !!selected_bb$long_max) %>%
  filter(latitude > !!selected_bb$lat_min) %>%
  filter(latitude < !!selected_bb$lat_max)

# check size of subset, for some countries this is very big thus requireing rounding of the coordinates so we have less places to reverse georeference
message(sprintf("The selected subset has %i rows",sparklyr::sdf_nrow(inat_subset)))


# Let's try to avoid having to reverse geocode every observation, as for some big countries R can't handle this out of the box (object size limits?)
# SEE ALSO: https://gis.stackexchange.com/questions/8650/measuring-accuracy-of-latitude-and-longitude/

inat_rounded <- 
  inat_subset %>%
    mutate(longitude_rounded = round(longitude,decimals_to_round_to),
           latitude_rounded = round(latitude,decimals_to_round_to)) %>%
    mutate(loc_id = paste0(longitude_rounded,latitude_rounded)) 

inat_locs <- inat_rounded %>%
  select(loc_id, longitude_rounded, latitude_rounded) %>%
  sparklyr::distinct()

# Check howmany unique locations we end up with after rounding
message(sprintf("Found %i unique localities after rounding",sparklyr::sdf_nrow(inat_locs)))

# reverse georeference
## use base:with instead of dplyr:pull to do reverse georeferencing in the local r environement

rev_georeferenced <- with(sparklyr::collect(inat_locs), 
       tibble(
         loc_id = loc_id,
         country = maps::map.where(database = "world", x = longitude_rounded, y = latitude_rounded)
       )
    )
sdf_copy_to(sc,rev_georeferenced,name = "cc_rounded", overwrite = TRUE)

# alternative, slower but base:with() warns about it's use in functions    
# sdf_copy_to(sc,
#            tibble(loc_id = pull(inat_locs,loc_id),
#                   country=maps::map.where(database = "world", x = pull(inat_locs,longitude_rounded), y = pull(inat_locs,latitude_rounded))),
#            name = "cc_rounded", overwrite = TRUE)

# join back to the original subset to attatch the localities to all of the observations
#inat_rounded_revgeoloc <- sparklyr::left_join(inat_rounded,sdf_sql(sc,"SELECT * FROM cc_rounded"), by = "loc_id")
inat_rounded_revgeoloc <- sparklyr::left_join(inat_rounded,spark_read_table(sc,"cc_rounded"), by = "loc_id")
sdf_register(inat_rounded_revgeoloc,name="countries")

# filter mechanism, drop observations that didn't geocode to the selected country
cc_tally <- sdf_sql(sc,"SELECT country,COUNT(*) as N FROM countries GROUP BY country ORDER BY N DESC") %>% sdf_collect()
if(countrycode::countrycode(selected_country, origin= "iso2c", destination="country.name") %>% stringr::str_replace("&","and") %in% pull(cc_tally,country)){
  inat_subset <- spark_read_table(sc,"countries") %>%
    filter(country == stringr::str_replace(countrycode::countrycode(selected_country, origin= "iso2c", destination="country.name"),"&","and"))} else {
  inat_subset <- spark_read_table(sc,"countries") %>%
    filter(country == pull(dplyr::slice(cc_tally,1),country))
}

# drop records of observers with less than the cutoff records
active_observers <- filter(count(inat_subset,observer_id),n>(cutoff-1)) %>% pull(observer_id)
inat_subset <- filter(inat_subset, observer_id %in% active_observers)
  
# print a short message about the result, the rowcount in the end is an expensive step that we don't really need
message(
    sprintf("passed %s: %s, subsetting resulted in %i records",
    selected_country,
    countrycode::countrycode(selected_country, origin = "iso2c", destination = "country.name"), sdf_nrow(inat_subset)
        )
    )
# return subset
return(inat_subset)
  }
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <pre style = 'font-size:10p'></pre><pre style = 'font-size:10p'>
# </pre>

# %%
# %r
# test with afghanistan
cz <- fetch_countrywise("CZ")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <pre style = 'font-size:10p'>The selected subset has 278940 rows
# Warning: ORDER BY is ignored in subqueries without LIMIT
# ℹ Do you need to move arrange() later in the pipeline or use window_order() instead?
# Found 26289 unique localities after rounding
#
# </pre>
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <pre style = 'font-size:10p'>Error: Cannot translate a data.frame to SQL.
# * Force evaluation in R with (e.g.) `!!df$x` or `local(df$x)`
#
#
# </pre>

# %%
# %r
# get european countries

euro_iso2c <- 
  bounding_boxes %>%
    mutate(continent = countrycode::countrycode(iso2c, origin="iso2c", destination="continent")) %>%
    filter(continent == "Europe") %>%
    pull(iso2c)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>

# %%
# %r


#let's create a list of spark dataframes with the results in per country

#purrr::map(euro_iso2c[1:3],fetch_countrywise) %>%
#  purrr::map2(euro_iso2c[1:3],~saveRDS(sdf_collect(.x),file=sprintf("/dbfs/FileStore/%s_inat.rds",.y)))
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>

# %% [markdown]
# In a loop, so we have intermediate saving

# %%
# %r
for(selected_cc in euro_iso2c[1:length(euro_iso2c)]){
  # we don't need to create a file we already have
  message(sprintf("considering %s", selected_cc))
  if(file.exists(sprintf("/dbfs/FileStore/%s_inat.rds",selected_cc))){
    message(sprintf("We already have %s_inat.rds for %s",
                    selected_cc,
                    countrycode::countrycode(selected_cc,
                                             origin = "iso2c",
                                             destination = "country.name")
                   )
           )
    next
  }
  
  out_sp <- fetch_countrywise(selected_cc) %>%
    sdf_collect(
    #  impl = "row-wise-iter"
    )
  # save the file, except if it's length zero. Then there is probably a problem with the translation between maps::map.where and countrycode::countrycode(destination="country.name")
  
  if(nrow(out_sp)>0){
    saveRDS(out_sp,
            file=sprintf("/dbfs/FileStore/%s_inat.rds",selected_cc)
           )
  message("saved, NEXT!!")} else { message(sprintf("problem with %s, not saved",selected_cc))}
}
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>

# %%
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
